# %%
import os
import pathlib
working_dir = pathlib.Path().absolute()
os.chdir(working_dir)

import numpy as np
import seaborn as sns
import pandas as pd
from PIL import Image
from svglib.svglib import svg2rlg

from matplotlib import pyplot
import matplotlib.pylab as plt 
# %matplotlib inline

# %%
with open('data/cubicasa5k/train.txt') as f:
    traintxt = f.readlines()
    
traintxt = [x.strip() for x in traintxt] 

train = []
for line in traintxt:
    train.append(np.asarray(Image.open('data/cubicasa5k'+line+'F1_scaled.png')))
# Out:
# /usr/share/anaconda3/lib/python3.7/site-packages/PIL/Image.py:2731: DecompressionBombWarning: Image size (90344064 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,

# %%
plt.imshow(train[0])

# %%
# WANT SVG!!
